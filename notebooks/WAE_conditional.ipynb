# %% [markdown]
# This notebook contains code from Hareesh Bahuleyan's 'probabilistic_nlg' repository  (https://github.com/HareeshBahuleyan/probabilistic_nlg) and runs the conditional WAE. It was designed speficially to be run in the Colaboratory environment.

# %% [markdown]
# ### SET UP ###

# %%
#I will attach my Drive so that I can easily load files.
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# ### UTILS ###

# %%
import numpy as np
import gensim
import re
from nltk.tokenize import word_tokenize
from nltk.translate.bleu_score import corpus_bleu
from nltk.collocations import BigramCollocationFinder
from nltk.probability import FreqDist
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from matplotlib import pyplot as plt
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

def calculate_bleu_scores(references, hypotheses):
    """
    Calculates BLEU 1-4 scores based on NLTK functionality
    Args:
        references: List of reference sentences
        hypotheses: List of generated sentences
    Returns:
        bleu_1, bleu_2, bleu_3, bleu_4: BLEU scores
    """
    bleu_1 = np.round(100 * corpus_bleu(references, hypotheses, weights=(1.0, 0., 0., 0.)), decimals=2)
    bleu_2 = np.round(100 * corpus_bleu(references, hypotheses, weights=(0.50, 0.50, 0., 0.)), decimals=2)
    bleu_3 = np.round(100 * corpus_bleu(references, hypotheses, weights=(0.34, 0.33, 0.33, 0.)), decimals=2)
    bleu_4 = np.round(100 * corpus_bleu(references, hypotheses, weights=(0.25, 0.25, 0.25, 0.25)), decimals=2)
    return bleu_1, bleu_2, bleu_3, bleu_4


def calculate_ngram_diversity(corpus):
    """
    Calculates unigram and bigram diversity
    Args:
        corpus: tokenized list of sentences sampled
    Returns:
        uni_diversity: distinct-1 score
        bi_diversity: distinct-2 score
    """
    bigram_finder = BigramCollocationFinder.from_words(corpus)
    bi_diversity = len(bigram_finder.ngram_fd) / bigram_finder.N

    dist = FreqDist(corpus)
    uni_diversity = len(dist) / len(corpus)

    return uni_diversity, bi_diversity


def calculate_entropy(corpus):
    """
    Calculates diversity in terms of entropy (using unigram probability)
    Args:
        corpus: tokenized list of sentences sampled
    Returns:
        ent: entropy on the sample sentence list
    """
    fdist = FreqDist(corpus)
    total_len = len(corpus)
    ent = 0
    for k, v in fdist.items():
        p = v / total_len

        ent += -p * np.log(p)

    return ent

def get_dict(sentences, filters, max_num_words, max_vocab_size):
     
    sentences = [' '.join(word_tokenize(s)[:max_num_words]) for s in sentences]

    tokenizer = Tokenizer(filters=filters)
    tokenizer.fit_on_texts(sentences)

    word_index = dict()
    word_index['PAD'] = 0
    word_index['UNK'] = 1
    word_index['GO'] = 2
    word_index['EOS'] = 3

    for i, word in enumerate(dict(tokenizer.word_index).keys()):
        word_index[word] = i + 4

    tokenizer.word_index = word_index
    x = tokenizer.texts_to_sequences(list(sentences))

    for i, seq in enumerate(x):
        if any(t >= max_vocab_size for t in seq):
            seq = [t if t < max_vocab_size else word_index['UNK'] for t in seq]
        seq.append(word_index['EOS'])
        x[i] = seq

    x = pad_sequences(x, padding='post', truncating='post', maxlen=max_num_words, value=word_index['PAD'])

    word_index = {k: v for k, v in word_index.items() if v < max_vocab_size}

    return word_index
  

def tokenize_sequence(sentences, filters, max_num_words, word_index):
    """
    Tokenizes a given input sequence of words.
    Args:
        sentences: List of sentences
        filters: List of filters/punctuations to omit (for Keras tokenizer)
        max_num_words: Number of words to be considered in the fixed length sequence
        max_vocab_size: Number of most frequently occurring words to be kept in the vocabulary
    Returns:
        x : List of padded/truncated indices created from list of sentences
        word_index: dictionary storing the word-to-index correspondence
    """

    sentences = [' '.join(word_tokenize(s)[:max_num_words]) for s in sentences]

    tokenizer = Tokenizer(filters=filters, oov_token = True)
    tokenizer.word_index = word_index
    x = tokenizer.texts_to_sequences(list(sentences))

    for i, seq in enumerate(x):
        if any(t == None for t in seq):
            seq = [t if t != None else word_index['UNK'] for t in seq]
        seq.append(word_index['EOS'])
        x[i] = seq

    x = pad_sequences(x, padding='post', truncating='post', maxlen=max_num_words, value=word_index['PAD'])

    return x


def create_embedding_matrix(word_index, embedding_dim, w2v_path):
    """
    Create the initial embedding matrix for TF Graph.
    Args:
        word_index: dictionary storing the word-to-index correspondence
        embedding_dim: word2vec dimension
        w2v_path: file path to the w2v pickle file
    Returns:
        embeddings_matrix : numpy 2d-array with word vectors
    """
    w2v_model = gensim.models.Word2Vec.load(w2v_path)
    embeddings_matrix = np.random.uniform(-0.05, 0.05, size=(len(word_index), embedding_dim))
    for word, i in word_index.items():
        try:
            embeddings_vector = w2v_model[word]
            embeddings_matrix[i] = embeddings_vector
        except KeyError:
            pass

    return embeddings_matrix


def get_sentences(file_path):
    with open(file_path, 'r') as f:
        data = f.readlines()

    return data


def clean_sentence(sent):
    sent = re.sub(r'[^\w\s\?\.\,]', '', sent.strip().lower())  # Lower case, remove punctuations (except , ? .)
    sent = re.sub(r'(([a-z]*)\d+.?\d*\%?)', ' NUM ', sent.strip())  # Replace Numbers with <NUM> token
    return sent


def get_batches(x, batch_size):
    """
    Generate inputs and targets in a batch-wise fashion for feed-dict
    Args:
        x: entire source sequence array
        batch_size: batch size
    Returns:
        x_batch, y_batch, sentence_length
    """

    for batch_i in range(0, len(x) // batch_size):
        start_i = batch_i * batch_size
        x_batch = x[start_i:start_i + batch_size]
        y_batch = x[start_i:start_i + batch_size]

        sentence_length = [np.count_nonzero(seq) for seq in x_batch]

        yield x_batch, y_batch, sentence_length


def get_batches_xy(x, y, labels,batch_size):
    """
    Generate inputs and targets in a batch-wise fashion for feed-dict
    Args:
        x: entire source sequence array
        y: entire output sequence array
        batch_size: batch size
    Returns:
        x_batch, y_batch, source_sentence_length, target_sentence_length
    """

    for batch_i in range(0, len(x) // batch_size):
        start_i = batch_i * batch_size
        x_batch = x[start_i:start_i + batch_size]
        y_batch = y[start_i:start_i + batch_size]
        label_batch = labels[start_i: start_i + batch_size]
        label_batch = np.asarray(label_batch)
        label_batch = np.reshape(label_batch, [batch_size,1])

        source_sentence_length = [np.count_nonzero(seq) for seq in x_batch]
        target_sentence_length = [np.count_nonzero(seq) for seq in y_batch]
        

        yield x_batch, y_batch, label_batch, source_sentence_length, target_sentence_length


def create_data_split(x, y, dataset_sizes):
    """
    Create test-train split according to previously defined CSV files
    Depending on the experiment - qgen or dialogue
    Args:
        x: input sequence of indices
        y: output sequence of indices
    Returns:
        x_train, y_train, x_val, y_val, x_test, y_test: train val test split arrays
    """

    train_size, val_size, test_size = dataset_sizes[0], dataset_sizes[1], dataset_sizes[2],

    train_indices = range(train_size)
    val_indices = range(train_size, train_size + val_size)
    test_indices = range(train_size + val_size, train_size + val_size + test_size)

    x_train = x[train_indices]
    y_train = y[train_indices]
    x_val = x[val_indices]
    y_val = y[val_indices]
    x_test = x[test_indices]
    y_test = y[test_indices]

    return x_train, y_train, x_val, y_val, x_test, y_test


def plot_2d(zvectors, labels, method):
    if method == 'tsne':
        cluster = TSNE(n_components=2, random_state=17)
    else:  # PCA
        cluster = PCA(n_components=2, random_state=17)

    cluster_result = cluster.fit_transform(X=zvectors)
    labels = labels[:cluster_result.shape[0]]
    labels = np.array(labels)

    class_dict = {0: 'automobile', 1: 'home and kitchen'}
    fig, ax = plt.subplots()
    ax.figure.set_size_inches(w=10, h=10)
    ax.scatter(cluster_result[np.where(labels == 0), 0], cluster_result[np.where(labels == 0), 1], s=6,
               label=class_dict[0])
    ax.scatter(cluster_result[np.where(labels == 1), 0], cluster_result[np.where(labels == 1), 1], s=6,
               label=class_dict[1])
    plt.grid()
    plt.legend(fontsize=12)
    plt.show()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### EMBEDDINGS ###

# %%
import os
import gensim
import numpy as np
from nltk.tokenize import word_tokenize

def main():

    combined_data = get_sentences(file_path = '/content/drive/My Drive/noisy_data.txt')
    print('[INFO] Number of sentences = {}'.format(len(combined_data)))

    sentences = [s.strip() for s in combined_data]
    np.random.shuffle(sentences)
    sentences = [word_tokenize(s) for s in sentences]
    w2v_model = gensim.models.Word2Vec(sentences,
                                       size=300,
                                       min_count=1,
                                       iter=50)
    if not os.path.exists('w2v_models'):
        os.mkdir('w2v_models')

    w2v_model.save('/content/drive/My Drive/w2v_models/embeddings.pkl')
    print('[INFO] Word embeddings pre-trained successfully')


#if __name__ == '__main__':
#    main()

# %% [markdown]
# ### DECODER ###

# %%
import collections
import tensorflow as tf
from tensorflow.contrib.seq2seq.python.ops import decoder
from tensorflow.contrib.seq2seq.python.ops import helper as helper_py
from tensorflow.python.framework import dtypes
from tensorflow.python.framework import ops
from tensorflow.python.framework import tensor_shape
from tensorflow.python.layers import base as layers_base
from tensorflow.python.ops import rnn_cell_impl
from tensorflow.python.util import nest

__all__ = [
    "BasicDecoderOutput",
    "BasicDecoder",
]


class BasicDecoderOutput(collections.namedtuple("BasicDecoderOutput", ("rnn_output", "sample_id"))):
    pass


class BasicDecoder(decoder.Decoder):
    """Basic sampling decoder."""

    def __init__(self, cell, helper, initial_state, latent_vector, output_layer=None):
        """Initialize BasicDecoder.
        Args:
          cell: An `RNNCell` instance.
          helper: A `Helper` instance.
          initial_state: A (possibly nested tuple of...) tensors and TensorArrays.
            The initial state of the RNNCell.
          output_layer: (Optional) An instance of `tf.layers.Layer`, i.e.,
            `tf.layers.Dense`.  Optional layer to apply to the RNN output prior
            to storing the result or sampling.
        Raises:
          TypeError: if `cell`, `helper` or `output_layer` have an incorrect type.
        """
        #if not rnn_cell_impl._like_rnncell(cell):  # pylint: disable=protected-access
        #    raise TypeError("cell must be an RNNCell, received: %s" % type(cell))
        if not isinstance(helper, helper_py.Helper):
            raise TypeError("helper must be a Helper, received: %s" % type(helper))
        if (output_layer is not None and not isinstance(output_layer, layers_base.Layer)):
            raise TypeError("output_layer must be a Layer, received: %s" % type(output_layer))
        self._cell = cell
        self._helper = helper
        self._initial_state = initial_state
        self._output_layer = output_layer
        self._latent_vector = latent_vector

    @property
    def batch_size(self):
        return self._helper.batch_size

    def _rnn_output_size(self):
        size = self._cell.output_size
        if self._output_layer is None:
            return size
        else:
      # To use layer's compute_output_shape, we need to convert the
      # RNNCell's output_size entries into shapes with an unknown
      # batch size.  We then pass this through the layer's
      # compute_output_shape and read off all but the first (batch)
      # dimensions to get the output size of the rnn with the layer
      # applied to the top.
            output_shape_with_unknown_batch = nest.map_structure(
            lambda s: tensor_shape.TensorShape([None]).concatenate(s),
            size)
            layer_output_shape = self._output_layer.compute_output_shape(  # pylint: disable=protected-access
                    output_shape_with_unknown_batch)
        return nest.map_structure(lambda s: s[1:], layer_output_shape)

    @property
    def output_size(self):
    # Return the cell output and the id
        return BasicDecoderOutput(
            rnn_output=self._rnn_output_size(),
            sample_id=tensor_shape.TensorShape([]))

    @property
    def output_dtype(self):
        # Assume the dtype of the cell is the output_size structure
        # containing the input_state's first component's dtype.
        # Return that structure and int32 (the id)
        dtype = nest.flatten(self._initial_state)[0].dtype
        return BasicDecoderOutput(
            nest.map_structure(lambda _: dtype, self._rnn_output_size()),
            dtypes.int32)

    def initialize(self, name=None):
        """Initialize the decoder.
        Args:
          name: Name scope for any created operations.
        Returns:
          `(finished, first_inputs, initial_state)`.
        """
        # Concatenate the latent vector to the 1st input to the decoder LSTM, i.e, the <GO> embedding + latent vector
        return (self._helper.initialize()[0], tf.concat([self._helper.initialize()[1], self._latent_vector], axis=-1)) + (self._initial_state,)

    def step(self, time, inputs, state, name=None):
        """Perform a decoding step.
        Args:
          time: scalar `int32` tensor.
          inputs: A (structure of) input tensors.
          state: A (structure of) state tensors and TensorArrays.
          name: Name scope for any created operations.
        Returns:
          `(outputs, next_state, next_inputs, finished)`.
        """
        with ops.name_scope(name, "BasicDecoderStep", (time, inputs, state)):
            cell_outputs, cell_state = self._cell(inputs, state)

            if self._output_layer is not None:
                cell_outputs = self._output_layer(cell_outputs)
            sample_ids = self._helper.sample(
                            time=time, outputs=cell_outputs, state=cell_state)
            (finished, next_inputs, next_state) = self._helper.next_inputs(
                                                  time=time,
                                                  outputs=cell_outputs,
                                                  state=cell_state,
                                                  sample_ids=sample_ids)

            # Concatenate the latent vector to the predicted word's embedding
            next_inputs = tf.concat([next_inputs, self._latent_vector], axis=-1)

        outputs = BasicDecoderOutput(cell_outputs, sample_ids)

        return (outputs, next_state, next_inputs, finished)

# %% [markdown]
# ### MODEL ###

# %%
import time
import pickle
import tensorflow as tf
import numpy as np
import os
from tqdm import tqdm
from nltk.tokenize import word_tokenize
from tensorflow.python.layers.core import Dense

class DetWAEModel(object):

    def __init__(self, config, embeddings_matrix, word_index):

        self.config = config

        self.lstm_hidden_units = config['lstm_hidden_units']
        self.embedding_size = config['embedding_size']
        self.latent_dim = config['latent_dim']
        self.num_layers = config['num_layers']
        
        self.lambda_val = config['lambda_val']

        self.vocab_size = config['vocab_size']
        self.num_tokens = config['num_tokens']

        self.dropout_keep_prob = config['dropout_keep_prob']

        self.initial_learning_rate = config['initial_learning_rate']
        self.learning_rate_decay = config['learning_rate_decay']
        self.min_learning_rate = config['min_learning_rate']

        self.batch_size = config['batch_size']
        self.epochs = config['n_epochs']

        self.embeddings_matrix = embeddings_matrix
        self.word_index = word_index
        self.idx_word = dict((i, word) for word, i in word_index.items())

        self.logs_dir = config['logs_dir']
        self.model_checkpoint_dir = config['model_checkpoint_dir']
        self.bleu_path = config['bleu_path']

        self.pad = self.word_index['PAD']
        self.eos = self.word_index['EOS']
        self.unk = self.word_index['UNK']
        
        self.epoch_bleu_score_val = {'1': [], '2': [], '3': [], '4': []}
        self.log_str = []

        self.build_model()

    def build_model(self):
        print("[INFO] Building Model ...")

        self.init_placeholders()
        self.embedding_layer()
        self.build_encoder()
        self.build_latent_space()
        self.sample_gaussian()
        self.build_decoder()
        self.loss()
        self.optimize()
        self.summary()

    def init_placeholders(self):
        with tf.name_scope("model_inputs"):
            # Create palceholders for inputs to the model
            self.input_data = tf.placeholder(tf.int32, [self.batch_size, self.num_tokens], name='input') # batch x maxlen
            self.target_data = tf.placeholder(tf.int32, [self.batch_size, self.num_tokens], name='targets') # batch x maxlen
            self.labels = tf.placeholder(tf.float32, [self.batch_size,1], name = 'labels') #batch x 1
            #self.labels = tf.reshape(self.labels,[self.batch_size, 1])
            self.lr = tf.placeholder(tf.float32, name='learning_rate', shape=())
            self.keep_prob = tf.placeholder(tf.float32, name='keep_prob')  # Dropout Keep Probability
            self.source_sentence_length = tf.placeholder(tf.int32, shape=(self.batch_size,),
                                                         name='source_sentence_length') # batch
            self.target_sentence_length = tf.placeholder(tf.int32, shape=(self.batch_size,),
                                                         name='target_sentence_length') # batch
            self.lambda_coeff = tf.placeholder(tf.float32, name='lambda_coeff', shape=())

    def embedding_layer(self):
        with tf.name_scope("word_embeddings"):
            self.embeddings = tf.Variable(
                initial_value=np.array(self.embeddings_matrix, dtype=np.float32),
                dtype=tf.float32, trainable=False)
            self.enc_embed_input = tf.nn.embedding_lookup(self.embeddings, self.input_data) # batch x maxlen x embed_dim
            self.enc_embed_input = self.enc_embed_input[:, :tf.reduce_max(self.source_sentence_length), :]

            with tf.name_scope("decoder_inputs"):
                # shifted = tf.strided_slice(self.target_data, [0, 0], [self.batch_size, -1], [1, 1],
                #                          name='slice_input')  # Minus 1 implies everything till the last dim
                shifted = self.target_data[:,:-1] # batch x (maxlen - 1)
                self.dec_input = tf.concat([tf.fill([self.batch_size, 1], self.word_index['GO']), shifted], 1,
                                           name='dec_input') # batch x maxlen
                self.dec_embed_input = tf.nn.embedding_lookup(self.embeddings, self.dec_input)
                self.max_tar_len = tf.reduce_max(self.target_sentence_length)
                self.dec_embed_input = self.dec_embed_input[:, :self.max_tar_len, :] # batch x maxlen x embed_dim
                # self.dec_embed_input = tf.nn.dropout(self.dec_embed_input, keep_prob=self.keep_prob)

    def build_encoder(self):
        with tf.name_scope("encode"):
            for layer in range(self.num_layers):
                with tf.variable_scope('encoder_{}'.format(layer + 1)):
                    cell_fw = tf.contrib.rnn.LayerNormBasicLSTMCell(self.lstm_hidden_units)
                    cell_fw = tf.contrib.rnn.DropoutWrapper(cell_fw, input_keep_prob=self.keep_prob)

                    cell_bw = tf.contrib.rnn.LayerNormBasicLSTMCell(self.lstm_hidden_units)
                    cell_bw = tf.contrib.rnn.DropoutWrapper(cell_bw, input_keep_prob=self.keep_prob)

                    self.enc_output, self.enc_state = tf.nn.bidirectional_dynamic_rnn(cell_fw,
                                                                                      cell_bw,
                                                                                      self.enc_embed_input,
                                                                                      self.source_sentence_length,
                                                                                      dtype=tf.float32)

            # Join outputs since we are using a bidirectional RNN
            self.h_N = tf.concat([self.enc_state[0][1], self.enc_state[1][1]], axis=-1,
                                 name='h_N')  # Concatenated h from the fw and bw LSTMs
            self.enc_outputs = tf.concat([self.enc_output[0], self.enc_output[1]], axis=-1, name='encoder_outputs')

    def build_latent_space(self):
        with tf.name_scope("latent_space"):
            self.z_tilda_pre = Dense(self.latent_dim, name='z_tilda')(self.h_N) # [batch_size x latent_dim]
            self.z_tilda = tf.concat([self.z_tilda_pre, self.labels], axis = 1)

    def sample_gaussian(self):
        with tf.name_scope('sample_gaussian'):
            # Random sample from Gaussian prior
            self.z_sampled_pre = tf.random_normal([self.batch_size, self.latent_dim], name='z_sampled') # Dimension [batch_size x latent_dim]
            self.z_sampled = tf.concat([self.z_sampled_pre, self.labels], axis = 1)

    def build_decoder(self):
        with tf.variable_scope("decode"):
            for layer in range(self.num_layers):
                with tf.variable_scope('decoder_{}'.format(layer + 1)):
                    dec_cell = tf.contrib.rnn.LayerNormBasicLSTMCell(2 * self.lstm_hidden_units)
                    dec_cell = tf.contrib.rnn.DropoutWrapper(dec_cell, input_keep_prob=self.keep_prob)

            self.output_layer = Dense(self.vocab_size)

            self.init_state = dec_cell.zero_state(self.batch_size, tf.float32)

            with tf.name_scope("training_decoder"):
                training_helper = tf.contrib.seq2seq.TrainingHelper(inputs=self.dec_embed_input,
                                                                    sequence_length=self.target_sentence_length,
                                                                    time_major=False)

                training_decoder = BasicDecoder(dec_cell,
                                                              training_helper,
                                                              initial_state=self.init_state,
                                                              latent_vector=self.z_tilda,
                                                              output_layer=self.output_layer)

                self.training_logits, _state, _len = tf.contrib.seq2seq.dynamic_decode(training_decoder,
                                                                                       output_time_major=False,
                                                                                       impute_finished=True,
                                                                                       maximum_iterations=self.num_tokens)

                self.training_logits = tf.identity(self.training_logits.rnn_output, 'logits')

            with tf.name_scope("validate_decoder"):
                start_token = self.word_index['GO']
                end_token = self.word_index['EOS']

                start_tokens = tf.tile(tf.constant([start_token], dtype=tf.int32), [self.batch_size],
                                       name='start_tokens')

                inference_helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(self.embeddings,
                                                                            start_tokens,
                                                                            end_token)

                inference_decoder = BasicDecoder(dec_cell,
                                                               inference_helper,
                                                               initial_state=self.init_state,
                                                               latent_vector=self.z_tilda,
                                                               output_layer=self.output_layer)

                self.validate_logits, _state, _len = tf.contrib.seq2seq.dynamic_decode(inference_decoder,
                                                                                        output_time_major=False,
                                                                                        impute_finished=True,
                                                                                        maximum_iterations=self.num_tokens)


                self.validate_sent = tf.identity(self.validate_logits.sample_id, name='predictions')

            with tf.name_scope("inference_decoder"):
                start_token = self.word_index['GO']
                end_token = self.word_index['EOS']

                start_tokens = tf.tile(tf.constant([start_token], dtype=tf.int32), [self.batch_size],
                                       name='start_tokens')

                inference_helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(self.embeddings,
                                                                            start_tokens,
                                                                            end_token)

                inference_decoder = BasicDecoder(dec_cell,
                                                               inference_helper,
                                                               initial_state=self.init_state,
                                                               latent_vector=self.z_sampled,
                                                               output_layer=self.output_layer)

                self.inference_logits, _state, _len = tf.contrib.seq2seq.dynamic_decode(inference_decoder,
                                                                                        output_time_major=False,
                                                                                        impute_finished=True,
                                                                                        maximum_iterations=self.num_tokens)

                self.inference_logits = tf.identity(self.inference_logits.sample_id, name='predictions')

                
    def mmd_penalty(self, sample_qz, sample_pz):
        n = self.batch_size
        n = tf.cast(n, tf.int32)
        nf = tf.cast(n, tf.float32)
        half_size = (n * n - n) / 2

        norms_pz = tf.reduce_sum(tf.square(sample_pz), axis=1, keep_dims=True)
        dotprods_pz = tf.matmul(sample_pz, sample_pz, transpose_b=True)
        distances_pz = norms_pz + tf.transpose(norms_pz) - 2. * dotprods_pz

        norms_qz = tf.reduce_sum(tf.square(sample_qz), axis=1, keep_dims=True)
        dotprods_qz = tf.matmul(sample_qz, sample_qz, transpose_b=True)
        distances_qz = norms_qz + tf.transpose(norms_qz) - 2. * dotprods_qz

        dotprods = tf.matmul(sample_qz, sample_pz, transpose_b=True)
        distances = norms_qz + tf.transpose(norms_pz) - 2. * dotprods

        if self.config['kernel'] == 'RBF':
            # Median heuristic for the sigma^2 of Gaussian kernel
            sigma2_k = tf.nn.top_k(
                tf.reshape(distances, [-1]), half_size).values[half_size - 1]
            sigma2_k += tf.nn.top_k(
                tf.reshape(distances_qz, [-1]), half_size).values[half_size - 1]
            # if opts['verbose']:
            #     sigma2_k = tf.Print(sigma2_k, [sigma2_k], 'Kernel width:')
            res1 = tf.exp(- distances_qz / 2. / sigma2_k)
            res1 += tf.exp(- distances_pz / 2. / sigma2_k)
            res1 = tf.multiply(res1, 1. - tf.eye(n))
            res1 = tf.reduce_sum(res1) / (nf * nf - nf)
            res2 = tf.exp(- distances / 2. / sigma2_k)
            res2 = tf.reduce_sum(res2) * 2. / (nf * nf)
            stat = res1 - res2
        elif self.config['kernel'] == 'IMQ':
            # k(x, y) = C / (C + ||x - y||^2)
            # C = tf.nn.top_k(tf.reshape(distances, [-1]), half_size).values[half_size - 1]
            # C += tf.nn.top_k(tf.reshape(distances_qz, [-1]), half_size).values[half_size - 1]
            #if opts['pz'] == 'normal':
            #    Cbase = 2. * opts['zdim'] * sigma2_p
            #elif opts['pz'] == 'sphere':
            #    Cbase = 2.
            #elif opts['pz'] == 'uniform':
                # E ||x - y||^2 = E[sum (xi - yi)^2]
                #               = zdim E[(xi - yi)^2]
                #               = const * zdim
            #    Cbase = opts['zdim']

            Cbase = 2. * self.config['latent_dim'] * 2. * 1. # sigma2_p # for normal sigma2_p = 1
            stat = 0.
            for scale in [.1, .2, .5, 1., 2., 5., 10.]:
                C = Cbase * scale
                res1 = C / (C + distances_qz)
                res1 += C / (C + distances_pz)
                res1 = tf.multiply(res1, 1. - tf.eye(n))
                res1 = tf.reduce_sum(res1) / (nf * nf - nf)
                res2 = C / (C + distances)
                res2 = tf.reduce_sum(res2) * 2. / (nf * nf)
                stat += res1 - res2
        return stat

    def loss(self):
        with tf.name_scope('losses'):
            self.wasserstein_loss = self.mmd_penalty(self.z_sampled_pre, self.z_tilda_pre)

            # Create the weights for sequence_loss
            masks = tf.sequence_mask(self.target_sentence_length, self.num_tokens, dtype=tf.float32, name='masks')

            self.xent_loss = tf.contrib.seq2seq.sequence_loss(
                self.training_logits,
                self.target_data[:, :self.max_tar_len],
                weights=masks[:, :self.max_tar_len],
                average_across_batch=True)

            # L2-Regularization
            self.var_list = tf.trainable_variables()
            self.lossL2 = tf.add_n([tf.nn.l2_loss(v) for v in self.var_list if 'bias' not in v.name]) * 0.001

            self.cost = self.xent_loss + self.config['lambda_val'] * self.wasserstein_loss # + self.lossL2

    def optimize(self):
        # Optimizer
        with tf.name_scope('optimization'):
            optimizer = tf.train.AdamOptimizer(self.lr)
            # optimizer = tf.train.GradientDescentOptimizer(self.lr)

            # Gradient Clipping
            gradients = optimizer.compute_gradients(self.cost, var_list=self.var_list)
            capped_gradients = [(tf.clip_by_value(grad, -5., 5.), var) for grad, var in gradients if grad is not None]
            self.train_op = optimizer.apply_gradients(capped_gradients)

    def summary(self):
        with tf.name_scope('summaries'):
            tf.summary.scalar('xent_loss', tf.reduce_sum(self.xent_loss))
            tf.summary.scalar('l2_loss', tf.reduce_sum(self.lossL2))
            tf.summary.scalar("wasserstein_loss", tf.reduce_sum(self.wasserstein_loss))
            tf.summary.scalar('total_loss', tf.reduce_sum(self.cost))
            tf.summary.scalar('lambda', self.lambda_coeff)

            self.summary_op = tf.summary.merge_all()

    def monitor(self, input_val,output_val, label_val, sess, epoch_i, time_consumption):
        self.validate(sess, input_val, output_val, label_val)
        val_bleu_str = str(self.epoch_bleu_score_val['1'][-1]) + ' | ' \
                       + str(self.epoch_bleu_score_val['2'][-1]) + ' | ' \
                       + str(self.epoch_bleu_score_val['3'][-1]) + ' | ' \
                       + str(self.epoch_bleu_score_val['4'][-1])

        val_str = '\t\t Generated \t|\t Actual \n'
        for pred, ref in zip(self.val_pred[:20], self.val_ref[:20]):
            val_str += '\t\t' + pred + '\t|\t' + ref + '\n'

        print(val_str)
        #gl.log_writer.write(val_str)

        generated = self.random_sample_in_session(sess)

        #gl.log_writer.write(generated)

        log_thisepoch = 'Epoch {:>3}/{} - Time {:>6.1f}, Train loss: {:>3.2f}, Val BLEU: {}\n\n'.format(epoch_i,
                                                                                                        self.epochs,
                                                                                                        time_consumption,
                                                                                                        self.train_xent,
                                                                                                        val_bleu_str)

        print(log_thisepoch)
        #gl.log_writer.write(log_thisepoch)
        #gl.log_writer.flush()
    
        saver = tf.train.Saver()
        saver.save(sess, self.model_checkpoint_dir + str(epoch_i) + ".ckpt")

        # Save the validation BLEU scores so far
        #with open(self.bleu_path + gl.config_fingerprint + '.pkl', 'wb') as f:
        #    pickle.dump(self.epoch_bleu_score_val, f)

        self.log_str.append(log_thisepoch)

        #with open('bleu_logs.txt', 'w') as f:
        #    f.write('\n'.join(self.log_str))

    def train(self, input_train, input_val, output_train, output_val, label_train, label_val,checkpoint_return = True, checkpoint = None):

        print('[INFO] Training process started')

        learning_rate = self.initial_learning_rate
        iter_i = 0

        with tf.Session() as sess: 
            sess.run(tf.global_variables_initializer())
            
            if checkpoint_return:
                saver = tf.train.Saver()
                saver.restore(sess, checkpoint)
                print('RESTORED CHECKPOINT')
            
            writer = tf.summary.FileWriter(self.logs_dir, sess.graph)

            for epoch_i in range(1, self.epochs + 1):

                start_time = time.time()
                
                for batch_i, (input_batch, output_batch, label_batch, input_sent_lengths, output_sent_lengths) in enumerate(
                        get_batches_xy(input_train, output_train, label_train, self.batch_size)):

                    try:
                        iter_i += 1

                        _, _summary, self.train_xent = sess.run(
                            [self.train_op, self.summary_op, self.xent_loss],
                            feed_dict={self.input_data: input_batch, # <batch x maxlen>
                                       self.target_data: output_batch, # <batch x maxlen>
                                       self.labels: label_batch,
                                       self.lr: learning_rate,
                                       self.source_sentence_length: input_sent_lengths,
                                       self.target_sentence_length: output_sent_lengths,
                                       self.keep_prob: self.dropout_keep_prob,
                                       self.lambda_coeff: self.lambda_val,
                                       })

                        writer.add_summary(_summary, iter_i)

                    except Exception as e:
                        print(iter_i, e)
                        pass
                                  

                # Reduce learning rate, but not below its minimum value
                learning_rate = np.max([self.min_learning_rate, learning_rate * self.learning_rate_decay])
                time_consumption = time.time() - start_time
                self.monitor(input_val, output_val, label_val, sess, epoch_i, time_consumption)

    def validate(self, sess, input_val, output_val, label_val):
        # Calculate BLEU on validation data
        hypotheses_val = []
        references_val = []

        for batch_i, (input_batch, output_batch, label_batch, input_sent_lengths, output_sent_lengths) in enumerate(
                get_batches_xy(input_val, output_val, label_val, self.batch_size)):
            pred_sentences, self._validate_logits = sess.run(
                                     [self.validate_sent, self.validate_logits],
                                     feed_dict={self.input_data: input_batch,
                                                self.labels: label_batch,
                                                self.source_sentence_length: input_sent_lengths,
                                                self.keep_prob: 1.0,
                                                })


            for pred, actual in zip(pred_sentences, output_batch):
                hypotheses_val.append(
                    word_tokenize(
                        " ".join([self.idx_word[i] for i in pred if i not in [self.pad, -1, self.eos]])))
                references_val.append(
                    [word_tokenize(" ".join([self.idx_word[i] for i in actual if i not in [self.pad, -1, self.eos]]))])
            self.val_pred = ([" ".join(sent)    for sent in hypotheses_val])
            self.val_ref  = ([" ".join(sent[0]) for sent in references_val])

        bleu_scores = calculate_bleu_scores(references_val, hypotheses_val)

        self.epoch_bleu_score_val['1'].append(bleu_scores[0])
        self.epoch_bleu_score_val['2'].append(bleu_scores[1])
        self.epoch_bleu_score_val['3'].append(bleu_scores[2])
        self.epoch_bleu_score_val['4'].append(bleu_scores[3])

    def predict(self, checkpoint, x_test):
        pred_logits = []
        hypotheses_test = []
        references_test = []

        with tf.Session() as sess:
            sess.run(tf.global_variables_initializer())
            saver = tf.train.Saver()
            saver.restore(sess, checkpoint)

            for batch_i, (input_batch, output_batch, sent_lengths) in enumerate(
                    utils.get_batches(x_test, self.batch_size)):
                result = sess.run(self.validate_sent, feed_dict={self.input_data: input_batch,
                                                                    self.source_sentence_length: sent_lengths,
                                                                    self.keep_prob: 1.0,
                                                                    })

                pred_logits.extend(result)

                for pred, actual in zip(result, output_batch):
                    hypotheses_test.append(
                        word_tokenize(" ".join(
                            [self.idx_word[i] for i in pred if i not in [self.pad, -1, self.eos]])))
                    references_test.append([word_tokenize(
                        " ".join([self.idx_word[i] for i in actual if i not in [self.pad, -1, self.eos]]))])

            bleu_scores = utils.calculate_bleu_scores(references_test, hypotheses_test)

        print('BLEU 1 to 4 : {}'.format(' | '.join(map(str, bleu_scores))))

        return pred_logits

    def show_output_sentences(self, preds, x_test):
        for pred, actual in zip(preds, x_test):
            # Actual and generated
            print('A: {}'.format(
                " ".join([self.idx_word[i] for i in actual if i not in [self.pad, self.eos]])))
            print('G: {}\n'.format(
                " ".join([self.idx_word[i] for i in pred if i not in [self.pad, self.eos]])))

    def random_sample(self, checkpoint):

        with tf.Session() as sess:
            sess.run(tf.global_variables_initializer())
            saver = tf.train.Saver()
            saver.restore(sess, checkpoint)

            
            z_sampled = np.random.normal(size=(self.batch_size, self.latent_dim))
            result = sess.run(self.inference_logits,
                                feed_dict={self.z_sampled: z_sampled,
                                            self.keep_prob: 1.0,
                                            })

            for pred in result:
                sent = " ".join([self.idx_word[i] for i in pred if i not in [self.pad, self.eos]])
                print('G: {}'.format(sent))

    def random_sample_save(self, checkpoint, num_batches=1):

        with tf.Session() as sess:
            sess.run(tf.global_variables_initializer())
            saver = tf.train.Saver()
            saver.restore(sess, checkpoint)
            print('[INFO]: CHECKPOINT RESTORED')
            
            clean_samples = []
            noisy_samples = []
            
            num_batches = int(600000/self.batch_size)
            print('NUMBER OF SAMPLES: ', num_batches * self.batch_size)

            for i in range(num_batches):
                z_sampled = np.random.normal(size=(int(self.batch_size/2), self.latent_dim))
                z_sampled_new = np.concatenate([z_sampled, z_sampled], axis = 0)
                labels_0 = np.zeros([int(self.batch_size/2),1])
                labels_1 = np.ones([int(self.batch_size/2), 1])
                labels = np.concatenate([labels_0, labels_1], axis = 0)
                
                result = sess.run(self.inference_logits,feed_dict={self.z_sampled_pre: z_sampled_new, self.labels: labels, self.keep_prob: 1.0,})

                for pred in result[0:int(self.batch_size/2)]:
                    sent = " ".join([self.idx_word[i] for i in pred if i not in [self.pad, self.eos]])
                    clean_samples.append(sent)
                    
                for pred in result[int(self.batch_size/2):]:
                    sent = " ".join([self.idx_word[i] for i in pred if i not in [self.pad, self.eos]])
                    noisy_samples.append(sent)

        assert len(clean_samples) == len(noisy_samples), 'Sample lists should have same length'

        clean_file = '/content/drive/My Drive/wae_clean_samples.txt'
        noisy_file = '/content/drive/My Drive/wae_noisy_samples.txt'
        
        with open(clean_file, 'w') as f:
            f.write('\n'.join(clean_samples))
            
        with open(noisy_file, 'w') as f:
            f.write('\n'.join(noisy_samples))

    def random_sample_in_session(self, sess):
        z_sampled = np.random.normal(size=(int(self.batch_size/2), self.latent_dim))
        z_sampled_new = np.concatenate([z_sampled, z_sampled], axis = 0)
        labels_1 = np.ones([int(self.batch_size/2),1])
        labels_0 = np.zeros([int(self.batch_size/2), 1])
        labels = np.concatenate([labels_1, labels_0], axis = 0)
        result = sess.run(self.inference_logits,feed_dict={self.z_sampled_pre: z_sampled_new, self.labels: labels, self.keep_prob: 1.0,})

        print('Clean versions')
        generated = ''

        for pred in result[:10]:
            generated += '\t\t' + ' '.join([self.idx_word[i] for i in pred if i not in [self.pad, self.eos]]) + '\n'
        print(generated)
        
        print('Noisy versions')
        generated = ''

        for pred in result[32:42]:
            generated += '\t\t' + ' '.join([self.idx_word[i] for i in pred if i not in [self.pad, self.eos]]) + '\n'
        print(generated)
        
        return generated
                
    def linear_interpolate(self, checkpoint, num_samples):
        sampled = []
        for i in range(self.batch_size // num_samples):
            z = np.random.normal(0, 1, (2, self.latent_dim))
            s1_z = z[0]
            s2_z = z[1]
            s1_z = np.repeat(s1_z[None, :], num_samples, axis=0)
            s2_z = np.repeat(s2_z[None, :], num_samples, axis=0)
            steps = np.linspace(0, 1, num_samples)[:, None]
            sampled.append(s1_z * (1 - steps) + s2_z * steps)

        sampled = np.reshape(np.array(sampled), newshape=(self.batch_size, self.latent_dim))
        with tf.Session() as sess:
            sess.run(tf.global_variables_initializer())
            saver = tf.train.Saver()
            saver.restore(sess, checkpoint)

            result = sess.run(self.inference_logits,
                              feed_dict={self.z_sampled: sampled,
                                         self.keep_prob: 1.0,
                                         })

            for i, pred in enumerate(result):
                if i % num_samples == 0:
                    print()
                print('G: {}'.format(
                    " ".join([self.idx_word[i] for i in pred if i not in [self.pad, self.eos]])))
                
    def linear_interpolate_between_inputs(self, checkpoint, start_sent, end_sent, num_samples=8):

        # Convert seq of words to seq of indices
        # if the word is not present, use default in get(): UNK
        start_sent = word_tokenize(start_sent)
        end_sent = word_tokenize(end_sent)
        start_idx_seq = [self.word_index.get(word, self.unk) for word in start_sent] + [self.eos] 
        end_idx_seq = [self.word_index.get(word, self.unk) for word in end_sent] + [self.eos]  # Append EOS token
        start_idx_seq = np.concatenate([start_idx_seq, np.zeros(max(0, self.num_tokens - len(start_idx_seq)))])[
                      :self.num_tokens]
        end_idx_seq = np.concatenate([end_idx_seq, np.zeros(max(0, self.num_tokens - len(end_idx_seq)))])[
                        :self.num_tokens]

        # Reshape/tile so that the input has first dimension as batch size
        inp_idx_seq = np.tile(np.vstack([start_idx_seq, end_idx_seq]), [self.batch_size//2, 1])
        # source_sent_lengths = [np.count_nonzero(seq) for seq in inp_idx_seq]

        # Get z_vector of first and last sentence
        z_vecs = self.get_zvector(checkpoint, inp_idx_seq)

        sampled = []
        s1_z = z_vecs[0]
        s2_z = z_vecs[1]
        s1_z = np.repeat(s1_z[None, :], num_samples, axis=0)
        s2_z = np.repeat(s2_z[None, :], num_samples, axis=0)
        steps = np.linspace(0, 1, num_samples)[:, None]
        sampled.append(s1_z * (1 - steps) + s2_z * steps)

        sampled = np.tile(sampled[0], [self.batch_size//num_samples, 1])
        # sampled = np.reshape(np.array(sampled), newshape=(self.batch_size, self.latent_dim))
        with tf.Session() as sess:
            sess.run(tf.global_variables_initializer())
            saver = tf.train.Saver()
            saver.restore(sess, checkpoint)

            result = sess.run(self.inference_logits,
                              feed_dict={self.z_sampled: sampled,
                                         self.keep_prob: 1.0,
                                         })

            for i, pred in enumerate(result[:num_samples]):
                print('G: {}'.format(
                    " ".join([self.idx_word[i] for i in pred if i not in [self.pad, self.eos]])))

    def get_zvector(self, checkpoint, x_test):
        z_vecs = []
        with tf.Session() as sess:
            sess.run(tf.global_variables_initializer())
            saver = tf.train.Saver()
            saver.restore(sess, checkpoint)

            for batch_i, (input_batch, output_batch, sent_lengths) in enumerate(
                    utils.get_batches(x_test, self.batch_size)):
                result = sess.run(self.z_tilda, feed_dict={self.input_data: input_batch,
                                                           self.source_sentence_length: sent_lengths,
                                                           self.keep_prob: 1.0,
                                                           })
                z_vecs.extend(result)

        return np.array(z_vecs)

# %% [markdown]
# ### RUN MODEL ###

# %%
import argparse
import os

def model_argparse():
    parser = argparse.ArgumentParser()

    # parser.add_argument("--isDebug", type=bool, default=gl.isDebug, help='is debug')
    parser.add_argument("--device", type=str, default="0", help='tf device') # GPU 0 or 1
    parser.add_argument("--lstm_hidden_units", type=int, default=100, help='number of hidden units for the LSTM')
    parser.add_argument("--embedding_size", type=int, default=300, help='word embedding dimension')
    parser.add_argument("--num_layers", type=int, default=1, help='number of LSTM layers')
    parser.add_argument("--vocab_size", type=int, default=30000, help='vocabulary size')
    parser.add_argument("--num_tokens", type=int, default=20, help='max number of words/tokens in the input/generated sequence')
    
    parser.add_argument("--latent_dim", type=int, default=100, help='dimension of z-latent space')
    parser.add_argument("--batch_size", type=int, default=128, help='batch size')
    parser.add_argument("--n_epochs", type=int, default=20, help='number of epochs')

    parser.add_argument("--dropout_keep_prob", type=float, default=0.8, help='dropout keep probability')
    parser.add_argument("--initial_learning_rate", type=float, default=0.001, help='initial learning rate')
    parser.add_argument("--learning_rate_decay", type=float, default=1.0, help='learning rate decay')
    parser.add_argument("--min_learning_rate", type=float, default=0.00001, help='minimum learning rate')

    parser.add_argument("--lambda_val", type=float, default=0., help='initial value of lambda, i.e., MMD co-efficient')
    parser.add_argument("--kernel", type=str, default='IMQ', help='MMD loss based on kernel type from: IMQ or RBF ')

    parser.add_argument("--data", type=str, default='../data/snli_sentences_all.txt')
    parser.add_argument("--w2v_file", type=str, default='../w2v_models/w2v_300d_snli_all_sentences.pkl')
    parser.add_argument("--bleu_path", type=str, default='bleu/', help='path to save bleu scores')
    parser.add_argument("--model_checkpoint_dir", type=str, default='', help='path to save model checkpoints')
    parser.add_argument("--logs_dir", type=str, default='', help='path to save log files')

    parser.add_argument("--ckpt", type=str, default=None, help='checkpoint')

    config = dict()
    config['device'] = '0'
    config['lstm_hidden_units'] = 100
    config['embedding_size'] = 300
    config['vocab_size'] = 30000
    config['num_layers'] = 1
    config['num_tokens'] = 50
    config['latent_dim'] = 100
    config['batch_size'] = 64
    config['n_epochs'] = 500
    config['dropout_keep_prob'] = 0.8
    config['initial_learning_rate'] = 0.001
    config['learning_rate_decay'] = 0.
    config['min_learning_rate'] = 0.00001
    config['lambda_val'] = 3.0
    config['kernel'] = 'IMQ'
    config['data'] ='/content/drive/My Drive/fce_train_new.txt'
    config['w2v_file'] = '/content/drive/My Drive/w2v_models/embeddings.pkl'
    config['bleu_path'] = 'bleu/'
    config['model_checkpoint_dir'] = ''
    config['logs_dir'] = ''
    config['ckpt'] = '/content/drive/My Drive/models/full_snli_lambdaWAE3.0_batch64_kernel_IMQ_num_tokens_50/109.ckpt'
    
    
    # Output log file
    config_fingerprint = 'full_snli_' + \
            'lambdaWAE' + str(config['lambda_val']) + \
            '_batch' + str(config['batch_size']) + \
            '_kernel_' + str(config['kernel']) + \
            '_num_tokens_' + str(config['num_tokens'])
    
    if not isTrain:
        return config

    # Create directories for saving model runs and stats
    pwd = os.path.dirname('/content/drive/My Drive/')

    if not os.path.exists(pwd + '/bleu'):
        os.mkdir(pwd + '/bleu')
    
    if not os.path.exists(pwd + '/runs'):
        os.mkdir(pwd + '/runs')

    log_writer = open(pwd + '/runs/log_' + config_fingerprint, 'a')
    log_writer.write(str(config) + '\n')
    log_writer.flush()

    # Model checkpoint
    if not os.path.exists(pwd + '/models'):
        os.mkdir(pwd + '/models')
    model_path = pwd + '/models/' + config_fingerprint
    if not os.path.exists(model_path):
        os.mkdir(model_path)
    config['model_checkpoint_dir'] = model_path + '/'

    # Model summary directory
    if not os.path.exists(pwd + '/summary_logs'):
        os.mkdir(pwd + '/summary_logs')
    summary_path = pwd + '/summary_logs/' + config_fingerprint
    if not os.path.exists(summary_path):
        os.mkdir(summary_path)

    config['logs_dir'] = summary_path

    return config

# %%
import os
isTrain = True

config = model_argparse()

import tensorflow as tf
tf_config = tf.ConfigProto()
tf_config.gpu_options.allow_growth = True
sess = tf.Session(config=tf_config)

import numpy as np
from sklearn.model_selection import train_test_split

#np.random.seed(1337)

#Set up the different datasets 
combined_data = get_sentences(file_path = '/content/drive/My Drive/noisy_data.txt')
input_data = get_sentences(file_path = '/content/drive/My Drive/clean_data.txt')
output_data = get_sentences(file_path = '/content/drive/My Drive/noisy_data.txt')

labels = []
label_path = '/content/drive/My Drive/labels.txt'
with open(label_path, 'r') as f:
  label_data = f.readlines()
for item in label_data:
  item = item.rstrip()
  labels.append(int(item))
  #if item == '1':
  #  array1 = np.array([0,1])
  #  labels.append(array1)
  #elif item == '0':
  #  array2 = np.array([1,0])
  #  labels.append(array2)
  #else:
  #  print('Only two types possible')

print('[INFO] Number of sentences = {}'.format(len(combined_data)))

combined_sentences = [s.strip() for s in combined_data]
input_sentences = [s.strip() for s in input_data]
output_sentences = [s.strip() for s in output_data]

print('[INFO] Tokenizing input and output sequences')
filters = '!"#$%&()*+/:;<=>@[\\]^`{|}~\t\n'
      
word_index = get_dict(combined_sentences, filters,config['num_tokens'], config['vocab_size'])
input_sents = tokenize_sequence(input_sentences, filters, config['num_tokens'], word_index)
output_sents = tokenize_sequence(output_sentences, filters, config['num_tokens'], word_index)

print('[INFO] Split data into train-validation-test sets')

input_train, input_val, output_train, output_val, label_train, label_val = train_test_split(input_sents, output_sents, labels, test_size = 0.05, random_state = 10)

w2v = config['w2v_file']
embeddings_matrix = create_embedding_matrix(word_index,
                                                  config['embedding_size'],
                                                  w2v)

# Re-calculate the vocab size based on the word_idx dictionary
config['vocab_size'] = len(word_index)
# Out:
# [INFO] Number of sentences = 41944
# [INFO] Tokenizing input and output sequences
# [INFO] Split data into train-validation-test sets
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:142: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
#----------------------------------------------------------------#

model = DetWAEModel(config,
                    embeddings_matrix,
                    word_index)

checkpoint = config['ckpt']

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    saver = tf.train.Saver()
    saver.restore(sess, checkpoint)


model.train(input_train, input_val, output_train, output_val, label_train, label_val, checkpoint = checkpoint)
log_writer.close()

#----------------------------------------------------------------#
# Out:
# [INFO] Number of sentences = 41944
# [INFO] Tokenizing input and output sequences
# [INFO] Split data into train-validation-test sets
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:142: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# WARNING: Logging before flag parsing goes to stderr.
# W0819 08:46:19.223275 140304432768896 deprecation.py:323] From <ipython-input-6-5f8b8c41feff>:113: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# W0819 08:46:19.225140 140304432768896 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/rnn.py:464: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# [INFO] Building Model ...
# W0819 08:46:19.755205 140304432768896 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0819 08:46:19.907197 140304432768896 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/rnn.py:244: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0819 08:46:21.642755 140304432768896 deprecation.py:506] From <ipython-input-6-5f8b8c41feff>:216: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# W0819 08:46:28.632457 140304432768896 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# [INFO] Training process started
# RESTORED CHECKPOINT
# 		 Generated 	|	 Actual
# 		then the concert started , i was called one of the band for help , get lost the concert .	|	then the concert started , i was called from one of the staffs for help , finally i could get into the stadium .
# 		she can not keep secrets .	|	she is not keeping secrets .
# 		i spent some days in vienna , i had chance to help the pearl jam in the concert .	|	i spent some great days in vienna where i had the chance to help at the concert of pearl jam .
# 		it would be greatful if you would agree to change your plan .	|	it will be beutiful if you would agree to change your plan .
# 		when we arrived at the place where it happened , one man started running .	|	when we arrived at the place which it happened , one man started running away .
# 		it took us a little time to become friends and after that we were always together best .	|	it took us a few time to became best friend and after that we were always together .
# 		i still go to school and i plan go to the next year .	|	i still go to school and i plan to go to college next year .
# 		i was very happy to receive a letter from you .	|	i was very happy to receive a letter from you .
# 		yours sincerely	|	yours sincerely
# 		at the moment of all people can travel on the computer , i can buy everything , i can do anything from around the world , i could n't find anything for example , i could just say that in the other people can cook in the programme , i	|	in everytime of the day i can communicate with people of all nationality of the world , i can have informations about everything , i can buy something which i ca n't find in the shops of my town , so i can do anything just clicking on the mouse
# 		it was so exciting	|	it was so exciting
# 		finally , i can say that modern technologies people really helps everyday work .	|	finally , i can say that modern technology really helps people in their work .
# 		at the end , i could see that no discounts available for the theatre . i was really disappointed , it would start organizing a shopping for the end of june . i do n't know if the reason is a perfect evening out now , i want you	|	at end , i could see that the advertisement said , your perfect evening out . it was n't the perfect evening . now i 'm looking for a lawyer , because i want my money back , if do n't well you know the end of this
# 		i am very happy i would like to go two weeks at camp california . the first reason is basketball . i am good at this sport . i used to play tennis for a week .	|	i am very glad i can chose two activities while i will at the camp . i am keen on basketball , i played in my country for 7 years . i am good diffender .
# 		unfortunately , i am very disappointed about the organisation of your company .	|	unfortunatly i am a very disappointed about organisation in your company .
# 		we 're looking forwold to your reply .	|	we 're looking forward to your reply .
# 		i helped korn at a concert they had in the auditorium .	|	i helped korn at a concert they had at the auditorium .
# 		disappointed	|	disapponted
# 		after all these reasons , my best friend was disappointed , and that is why i ask you for my money back as soon as possible .	|	at last , for all these reasons my evening was horrible , and that is why i would like to ask you for my money back as soon as possible .
# 		love and kisses .	|	loves and kisses .
#
# Clean versions
# 		that is the sport that i find you would like to be the worst time i expected to get a rest .
# 		i answered to satisfied the number of all the money i need .
# 		we were also allowed to chose the perfect one , but to buy something to me , curious .
# 		after the show i 'm sorry that it looked a little bit of products , but unfortunately i could not buy anything in your theatre .
# 		i have been a student and it was very important for seeing your theatre .
# 		the first of i decided to visit it was n't the 13th age and so , there was a photograph .
# 		i do n't trust pat and is so others to show him
# 		and we 'll still ask them again .
# 		indeed , this would be included in love with my money and other for the time to go with the household .
# 		let you had to breath all the things i found only for my mother 's girlfriend .
#
# Noisy versions
# 		that is the sport i find that you would like to get a nice environment to the audience .
# 		i answered to satisfied the number of all the money i needed .
# 		we were also the year trying to decide , but to find out perfectly , perfectly appropriate me so much .
# 		after a good example , it was not very pleasant to look into a little bit of products , but unfortunately i could not have time without having gone .
# 		i have been a student and it was extremely important for yours holiday .
# 		the best thing i was looking forward to it and the awful work , but there was not a photograph .
# 		i hope to do it and we was not able to trust him and everyone would like to show her
# 		and we 'll still ask them again for the rest of them .
# 		please , this would be leaving in a love with my money and then to go out with the other groups .
# 		you could n't talk to have dinner because after the tone shoes i found out my own boyfriend .
#
# Epoch   1/500 - Time  352.8, Train loss: 0.62, Val BLEU: 74.34 | 59.68 | 50.26 | 42.89
#
#
# 		 Generated 	|	 Actual
# 		then the concert started , i was called one of the concert for me , i got to get lost in the stadium .	|	then the concert started , i was called from one of the staffs for help , finally i could get into the stadium .
# 		she can not keep secrets .	|	she is not keeping secrets .
# 		i spent some days in vienna , i had chance to help at the pearl jam where the concert had been .	|	i spent some great days in vienna where i had the chance to help at the concert of pearl jam .
# 		it would be greatful if you would agree to change your plan .	|	it will be beutiful if you would agree to change your plan .
# 		when we arrived at the place where he said that one day begins later .	|	when we arrived at the place which it happened , one man started running away .
# 		it took a time to become a little bit and after we are friends most of them .	|	it took us a few time to became best friend and after that we were always together .
# 		i still go to school and i plan go to the next year .	|	i still go to school and i plan to go to college next year .
# 		i was very happy to receive a letter from you .	|	i was very happy to receive a letter from you .
# 		yours sincerely	|	yours sincerely
# 		at the moment of all people can buy on the computer of the world , i can buy anything from all of things , i ca n't find anything on the television , so i can find anything that i can just pay for the computers , i can store	|	in everytime of the day i can communicate with people of all nationality of the world , i can have informations about everything , i can buy something which i ca n't find in the shops of my town , so i can do anything just clicking on the mouse
# 		it was so exciting	|	it was so exciting
# 		finally , i can say that modern technology helps people really helps in their work .	|	finally , i can say that modern technology really helps people in their work .
# 		at the end , i could see that the show was n't a perfect evening out , as you said , it was the worst . i would like to do my work because i 'm a bit happy that now i want to know this , about the money	|	at end , i could see that the advertisement said , your perfect evening out . it was n't the perfect evening . now i 'm looking for a lawyer , because i want my money back , if do n't well you know the end of this
# 		i am very happy i would like to go two weeks at the camp . i am good at this sport . i am a novice child and photography .	|	i am very glad i can chose two activities while i will at the camp . i am keen on basketball , i played in my country for 7 years . i am good diffender .
# 		unfortunately , i am very disappointed about the organisation of your company .	|	unfortunatly i am a very disappointed about organisation in your company .
# 		we 're looking forwold to your reply .	|	we 're looking forward to your reply .
# 		i helped korn at a concert they had in the auditorium .	|	i helped korn at a concert they had at the auditorium .
# 		disappointed	|	disapponted
# 		after all these reasons , my best friend was about me , and that is why i paid if possible would like to ask you for returning refund .	|	at last , for all these reasons my evening was horrible , and that is why i would like to ask you for my money back as soon as possible .
# 		love and kisses .	|	loves and kisses .
#
# Clean versions
# 		last months i find your hand the best thing for make you do , and i spent big fun .
# 		every person has so much to me in spite of famous people .
# 		i want to have a nice room and how the power of my home i have .
# 		especially , often your parents are looking forward to see some of swimming changes 1 .
# 		i was then to do something for you .
# 		i am not sure you 'd like to be a question , then i think i have to take a long time and think .
# 		they had n't been separated the deal of close tv and we started my friends .
# 		otherwise , you have to bring the smart clothes at the camp .
# 		for the person is so poor in home .
# 		therefore i 'm a member of the electric which were young to hear people .
#
# Noisy versions
# 		last months i find your opinion about the food , and she left every night i think we were not expecting .
# 		every person has so much to her in spite of famous and various items .
# 		i want to have a nice break at the jon and i 'm a teenager with my father .
# 		especially , often your parents are looking forward to see some of swimming changes 1 to travel .
# 		i was then to do something at which i am for you .
# 		i am not sure you 'd like to be a question , then i think i have to take a long time and think .
# 		they had n't been separated the deal of forgetting deal with the lights .
# 		otherwise , you have to bring the smart clothes at the camp .
# 		for the person is so poor in home as a developing .
# 		yours group 's experience which were impressive , especially a long conversation .
#
# Epoch   2/500 - Time  349.9, Train loss: 0.63, Val BLEU: 73.86 | 59.35 | 49.99 | 42.64
#
#
# 		 Generated 	|	 Actual
# 		then the concert started , i was one of the staff for help , i had to get into the stadium , where i could get lost .	|	then the concert started , i was called from one of the staffs for help , finally i could get into the stadium .
# 		she can not keep secrets .	|	she is not keeping secrets .
# 		i spent some more fun in vienna at the concert i had chance to organize the entire jam jam .	|	i spent some great days in vienna where i had the chance to help at the concert of pearl jam .
# 		it would be greatful if you would agree to change your plan .	|	it will be beutiful if you would agree to change your plan .
# 		when we arrived at the place where it happened , one man started running away .	|	when we arrived at the place which it happened , one man started running away .
# 		it took a time to become a little bit and after we all live together .	|	it took us a few time to became best friend and after that we were always together .
# 		i still go to school and i plan go to the college next year .	|	i still go to school and i plan to go to college next year .
# 		i was very happy to receive a letter from you .	|	i was very happy to receive a letter from you .
# 		yours sincerely	|	yours sincerely
# 		with the computer of the evenings of people i can go on the computer , i can do anything which i can just ever , of the advantages can buy everything i can do anything in the newspaper , so i can do something in the shop , i ca	|	in everytime of the day i can communicate with people of all nationality of the world , i can have informations about everything , i can buy something which i ca n't find in the shops of my town , so i can do anything just clicking on the mouse
# 		it was so exciting	|	it was so exciting
# 		finally , i can say that modern technology helps people really helps their life .	|	finally , i can say that modern technology really helps people in their work .
# 		at the end , i could see that the perfect evening out , as you said , this was n't the perfect evening out . i want once a week , i realised it was a perfect evening out now , as you want to know about the reason that	|	at end , i could see that the advertisement said , your perfect evening out . it was n't the perfect evening . now i 'm looking for a lawyer , because i want my money back , if do n't well you know the end of this
# 		i am very happy i would like to go back two weeks at camp california . the first is played in photography - i am good at this sport . i am a novice fan of my country .	|	i am very glad i can chose two activities while i will at the camp . i am keen on basketball , i played in my country for 7 years . i am good diffender .
# 		unfortunately , i am very disappointed about the organisation of your company .	|	unfortunatly i am a very disappointed about organisation in your company .
# 		we 're looking forwold to your reply .	|	we 're looking forward to your reply .
# 		i helped korn at a concert they had in the auditorium .	|	i helped korn at a concert they had at the auditorium .
# 		disappointed	|	disapponted
# 		after all these reasons , my best evening was that i am asking you and if i would like to ask you for my money back .	|	at last , for all these reasons my evening was horrible , and that is why i would like to ask you for my money back as soon as possible .
# 		love and kisses .	|	loves and kisses .
#
# Clean versions
# 		it means , i 'll make sure if there will have some timetable in the end and find out to find things .
# 		i send you much more attention at the time for my shopping .
# 		now , it 's my first problem i am with my student card .
# 		since the last night , nobody had to explain to our fight .
# 		in my opinion , that 's why i can pat was a teenager of crying and strong .
# 		to finish short 's opinion , there is a very terrible time .
# 		and i write this letter with the two people that california .
# 		of the reason i bought to have a little phone and when the next day for going to .
# 		i get to complete that doing it , who asked the two advice .
# 		in my winter i feel most of the times we had n't wanted to stay in all for girls , i would like to stay in their long time .
#
# Noisy versions
# 		it means , i would accept if they have to stay in the end and find out of important things to do .
# 		i hope you have lost getting on my list for everything .
# 		now , it 's my first problem i am with my italy .
# 		since the girl had to describe our mistake to pat with the truth .
# 		in my opinion , that 's why i can pat was a small and respected 's phone .
# 		to finish short 's opinion , there is a very terrible evening .
# 		and i said this at the entrance of the tickets and come with this .
# 		of the reason i bought that she was going to continue to the press and just to find everything .
# 		i learned that looking forward to get just wonder that he bought the concert .
# 		in my opinion i dress all the time they were n't able to join for every summer , even though i had just sing who wanted to sing .
#
# Epoch   3/500 - Time  350.6, Train loss: 0.63, Val BLEU: 73.79 | 59.36 | 49.87 | 42.41
#
#
# 		 Generated 	|	 Actual
# 		then the concert started , i was called one of the staff for help , i could get into the stadium , get lost .	|	then the concert started , i was called from one of the staffs for help , finally i could get into the stadium .
# 		she can not keep secrets .	|	she is not keeping secrets .
# 		i spent some days in vienna , i had chance to help at the pearl jam where the concert had some weeks .	|	i spent some great days in vienna where i had the chance to help at the concert of pearl jam .
# 		it would be greatful if you would change to your plan .	|	it will be beutiful if you would agree to change your plan .
# 		when we arrived at the place where it happened , one man started running 15 .	|	when we arrived at the place which it happened , one man started running away .
# 		it took us a time to become a little bit and after we always best time .	|	it took us a few time to became best friend and after that we were always together .
# 		i still go to school and i plan go to the next year .	|	i still go to school and i plan to go to college next year .
# 		i was very happy to receive a letter from you .	|	i was very happy to receive a letter from you .
# 		yours sincerely	|	yours sincerely
# 		at home with the list of people i can dress from all of the computer , so i can buy everything that i can do anything in the shops , i ca n't find anything in the shops , so i can just move my shoes to shop in order	|	in everytime of the day i can communicate with people of all nationality of the world , i can have informations about everything , i can buy something which i ca n't find in the shops of my town , so i can do anything just clicking on the mouse
# 		it was so exciting	|	it was so exciting
# 		finally , i can say that modern technology helps people really helps their work .	|	finally , i can say that modern technology really helps people in their work .
# 		at the end , i could n't see it , except the advertisement for this , the show was really late , i do n't know if the reason of my money i 'm a surprise , i did n't want to know a this moment for my money back	|	at end , i could see that the advertisement said , your perfect evening out . it was n't the perfect evening . now i 'm looking for a lawyer , because i want my money back , if do n't well you know the end of this
# 		i am very glad i 'd prefer to go back at the camp california . i am a good swimmer . i am quite good at this country . i am good at bouth for five years .	|	i am very glad i can chose two activities while i will at the camp . i am keen on basketball , i played in my country for 7 years . i am good diffender .
# 		unfortunately , i am very disappointed about the organisation of your company .	|	unfortunatly i am a very disappointed about organisation in your company .
# 		we 're looking forwold to your reply .	|	we 're looking forward to your reply .
# 		i helped korn at a concert they had in the auditorium .	|	i helped korn at a concert they had at the auditorium .
# 		disappointed	|	disapponted
# 		after all these reasons , my best friend was about me , and that is why i paid if i would like to ask you for my money back .	|	at last , for all these reasons my evening was horrible , and that is why i would like to ask you for my money back as soon as possible .
# 		love and kisses .	|	loves and kisses .
#
# Clean versions
# 		about the other reason we have received , it must be a surprise for you to start the university and june so long .
# 		how big money is put on your staff account
# 		but it 's worth later per cent of the concert , they would get some great pictures .
# 		pat 's the advertisement for me so there was no more understanding .
# 		i was lucky to have an excellent pictures , because there are more varied goods .
# 		however , i went to see the films and taking a picture for its relationships to see all the events around the school .
# 		yesterday i will have to go with pat teacher , so my mother 's mind about her .
# 		i like to start the news , and take some good news .
# 		with your latest fashions are a good thing , specially with all sport but the main work is because play played .
# 		i see danny brook and she was writing to the name of the performance i 'm very happy about .
#
# Noisy versions
# 		about the other problems we are supposed to have to start for a student , and it ca n't be taken to pass to your letter .
# 		how big money is put on you account to eat our meals
# 		but it finally , every one who got big money on earth , there would be lots of responsibility .
# 		pat 's the advertisement for a very formal weapons and nobody seemed there .
# 		i was glad to have a particular ticket because of other activities , particularly classical concerts .
# 		however , i went to see the seats and taking a good picture on our relationships trip to greenwich and we should keep the real information .
# 		yesterday i will have to go with pat , so i 'm telling her about my feelings .
# 		i like to start the language and take good photographs of course .
# 		with your latest fashions are a good thing but yesterday , we study only because is funny to play the dark .
# 		i see danny brook and she was writing to anybody about the star 's name , the first man .
#
# Epoch   4/500 - Time  350.8, Train loss: 0.65, Val BLEU: 74.32 | 59.86 | 50.43 | 43.01
#
#
# 		 Generated 	|	 Actual
# 		then the concert started , i was called one of the staff for help , i could get into the stadium , get lost .	|	then the concert started , i was called from one of the staffs for help , finally i could get into the stadium .
# 		she can not keep secrets .	|	she is not keeping secrets .
# 		i spent some days in vienna , i had chance to help at the pearl jam where the concert had been helping at the pearl jam .	|	i spent some great days in vienna where i had the chance to help at the concert of pearl jam .
# 		it would be greatful if you would agree to change your plan .	|	it will be beutiful if you would agree to change your plan .
# 		when we arrived at the place where he said , one hour 15 minutes later .	|	when we arrived at the place which it happened , one man started running away .
# 		it took us a little time to become more about it and after we always spent together .	|	it took us a few time to became best friend and after that we were always together .
# 		i still go to school and i plan go to the next year .	|	i still go to school and i plan to go to college next year .
# 		i was very happy to receive a letter from you .	|	i was very happy to receive a letter from you .
# 		yours sincerely	|	yours sincerely
# 		at the moment of all people can cook on the computer of people , i can get anywhere everything , i can buy anything from all of the day , i could n't find anything in the shops which i can do , i can just have time on television	|	in everytime of the day i can communicate with people of all nationality of the world , i can have informations about everything , i can buy something which i ca n't find in the shops of my town , so i can do anything just clicking on the mouse
# 		it was so exciting	|	it was so exciting
# 		finally , i can say that modern technology helps people really helps me in their work .	|	finally , i can say that modern technology really helps people in their work .
# 		at the end , i could see that if the show was n't perfect , it said a busy evening at the end of june . i 'm really disappointed by it , because i want my money back , as you wo n't do this , the perfect evening	|	at end , i could see that the advertisement said , your perfect evening out . it was n't the perfect evening . now i 'm looking for a lawyer , because i want my money back , if do n't well you know the end of this
# 		i am very happy i will have two weeks at camp california in the u.s.a . i am quite good at this sport , i am a good swimmer and photography .	|	i am very glad i can chose two activities while i will at the camp . i am keen on basketball , i played in my country for 7 years . i am good diffender .
# 		unfortunately , i am very disappointed about the organisation of your company .	|	unfortunatly i am a very disappointed about organisation in your company .
# 		we 're looking forwold to your reply .	|	we 're looking forward to your reply .
# 		i helped korn at a concert they had in the auditorium .	|	i helped korn at a concert they had at the auditorium .
# 		disappointed	|	disapponted
# 		after all this , my reasons were why i would like to ask you , and that is why my money back as soon as possible for compensation .	|	at last , for all these reasons my evening was horrible , and that is why i would like to ask you for my money back as soon as possible .
# 		love and kisses .	|	loves and kisses .
#
# Clean versions
# 		therefore i will show up on a second sports .
# 		i can tell you what the weather for extra two extra
# 		according to me , i 'm realy satisfied and send me some money .
# 		both people wants to travel and money for what is more convenient .
# 		this is the sport , i mean to study or should remind the biggest situation in the world , sometimes not work .
# 		in august , i mean that the main needs to have a old man .
# 		but i like yes about it , nevertheless in having trouble and help us the article .
# 		i am still write a letter in kim , when i found terrible time in a small place .
# 		i should be paid for some fast time and during this week i wasted time to decide some lessons .
# 		i 'd agree that every body have changed our grandmother , walking or less more than the school .
#
# Noisy versions
# 		therefore i will show up to the sports invitation .
# 		i can tell you what the rest of the trip .
# 		according to me , i 'm choosing swimming and my studies .
# 		both people wants to travel and money for what is convenient .
# 		this is the sport , i mean to get an deal with the hard side of life or not in the hard work .
# 		in august , i mean that the main needs to have a old man .
# 		but i like yes about it , i have contact with me a solution between casual and further .
# 		i am still recently , in a terrible story i have just felt in a short time , even jacob .
# 		i should be late after some shopping and to make my pocket money i spent in charge of serving and i wasted time .
# 		i 'd agree that every body have changed our grandmother , especially the old friends or less .
#
# Epoch   5/500 - Time  350.9, Train loss: 0.65, Val BLEU: 74.22 | 59.73 | 50.35 | 43.06
#
#
# 		 Generated 	|	 Actual
# 		then the concert started , i was called one of the staff for help me , i could get into the stadium .	|	then the concert started , i was called from one of the staffs for help , finally i could get into the stadium .
# 		she can not keep secrets .	|	she is not keeping secrets .
# 		i spent some days in vienna , i had chance to help at the pearl jam where the concert had been .	|	i spent some great days in vienna where i had the chance to help at the concert of pearl jam .
# 		it would be greatful if you would change to plan .	|	it will be beutiful if you would agree to change your plan .
# 		when we arrived at the place where one happened , a man started running away .	|	when we arrived at the place which it happened , one man started running away .
# 		it took us a little time to become more exiting and after that we are always together .	|	it took us a few time to became best friend and after that we were always together .
# 		i still go to school and i plan go to the college next year .	|	i still go to school and i plan to go to college next year .
# 		i was very happy to receive a letter from you .	|	i was very happy to receive a letter from you .
# 		yours sincerely	|	yours sincerely
# 		with the computer of the evenings , i can spend all of things on the computer , people can just buy anything i can find out of the advantages , i can pay for everything i just want , in the shops that i ca n't stand on the day	|	in everytime of the day i can communicate with people of all nationality of the world , i can have informations about everything , i can buy something which i ca n't find in the shops of my town , so i can do anything just clicking on the mouse
# 		it was so exciting	|	it was so exciting
# 		finally , i can say that modern technology helps people really helps in their work .	|	finally , i can say that modern technology really helps people in their work .
# 		at the end , i could see that if the show was n't perfect , i received your perfect evening out . it said at the end of the show . it was a horrible evening , because i do n't now want my money back .	|	at end , i could see that the advertisement said , your perfect evening out . it was n't the perfect evening . now i 'm looking for a lawyer , because i want my money back , if do n't well you know the end of this
# 		i am very happy i would like to go two weeks at camp california . the first reason is basketball . i am good at this hobby and i am a novice beginner .	|	i am very glad i can chose two activities while i will at the camp . i am keen on basketball , i played in my country for 7 years . i am good diffender .
# 		unfortunately , i am very disappointed about the organisation of your company .	|	unfortunatly i am a very disappointed about organisation in your company .
# 		we 're looking forwold to your reply .	|	we 're looking forward to your reply .
# 		i helped korn at a concert they had in the auditorium .	|	i helped korn at a concert they had at the auditorium .
# 		disappointed	|	disapponted
# 		after all these reasons , my choise was that i was disappointed and ask me for my money back , so as soon as possible .	|	at last , for all these reasons my evening was horrible , and that is why i would like to ask you for my money back as soon as possible .
# 		love and kisses .	|	loves and kisses .
#
# Clean versions
# 		in the other point i will pay to show all additional .
# 		consequently i read that the second time i want to play with competition .
# 		the theater i was organized the show , if you wanted to discuss about the exact .
# 		the third reason where i am taking up in the morning and in your timetable where you are wright .
# 		the first way of me was boring was not correct for the improvement but fashion .
# 		i hope you were happy to do , because of their work and i could visit it for the show .
# 		dear i am not perfectly , how difficult i would prefer my life .
# 		making up , studying how has help for my life , i will answer many questions .
# 		mainly it will be so because they arrived to its office arrived in time , but it was close to obtain .
# 		well , i want to take you for nature , so i hope and easily wherever you are often .
#
# Noisy versions
# 		so i will offer the other one of the problems to place .
# 		i read that the second time i 'm looking forward to watching tv .
# 		the other month was the excellent decision , and nobody told someone about the organisation .
# 		the third reasons where i am taking up for the whole time and in your programme , where is changing .
# 		the first way of me is boring was not correct one time .
# 		i hope you were happy to do , because of their work and i could visit it for the show .
# 		dear i would not love the letter now , with my new clothes .
# 		making it away , will help many things that i have to work with an dream , giving photos .
# 		mainly it will be so because they had been watching at home to watch trees .
# 		well , i do n't hesitate to thank you for easily , so easily i want you .
#
# Epoch   6/500 - Time  351.0, Train loss: 0.64, Val BLEU: 74.34 | 59.8 | 50.37 | 42.98
#
#
# 		 Generated 	|	 Actual
# 		then , the concert started i was called one of the staff for help , i could get into the stadium .	|	then the concert started , i was called from one of the staffs for help , finally i could get into the stadium .
# 		she can not keep secrets .	|	she is not keeping secrets .
# 		i spent some days in vienna , i had chance to help at the pearl jam where the concert had been helping .	|	i spent some great days in vienna where i had the chance to help at the concert of pearl jam .
# 		it would be greatful if you would agree to change your plan .	|	it will be beutiful if you would agree to change your plan .
# 		when we arrived at the place where he started running , one hour 15 .	|	when we arrived at the place which it happened , one man started running away .
# 		it took us a little time to become and best friends after that we were always together .	|	it took us a few time to became best friend and after that we were always together .
# 		i still go to school and i plan go to the next year .	|	i still go to school and i plan to go to college next year .
# 		i was very happy to receive a letter from you .	|	i was very happy to receive a letter from you .
# 		yours sincerely	|	yours sincerely
# 		at the moment of all people can spend time on the computer , i can contact with people , so that i can go anywhere , i ca n't find anything in the shops , i can just move my day by whatever i can do in the shopping centre	|	in everytime of the day i can communicate with people of all nationality of the world , i can have informations about everything , i can buy something which i ca n't find in the shops of my town , so i can do anything just clicking on the mouse
# 		it was so exciting	|	it was so exciting
# 		finally , i can say that modern technology helps people really helps people .	|	finally , i can say that modern technology really helps people in their work .
# 		at the end , i could n't see it , except your theatre restaurant , it was closed because i would like to say the real evening . it did n't finish my end of june . i 'm a happy surprise .	|	at end , i could see that the advertisement said , your perfect evening out . it was n't the perfect evening . now i 'm looking for a lawyer , because i want my money back , if do n't well you know the end of this
# 		i am very happy i would like to go two weeks at the camp . i am a full-time student . i am good at this sport , especially for my country .	|	i am very glad i can chose two activities while i will at the camp . i am keen on basketball , i played in my country for 7 years . i am good diffender .
# 		unfortunately , i am very disappointed about the organisation of your company .	|	unfortunatly i am a very disappointed about organisation in your company .
# 		we 're looking forwold to your reply .	|	we 're looking forward to your reply .
# 		i helped korn at a concert they had in the auditorium .	|	i helped korn at a concert they had at the auditorium .
# 		disappointed	|	disapponted
# 		lastly , all this evening was for my reasons , why i would like to ask you and if my money is possible to please , as soon as possible .	|	at last , for all these reasons my evening was horrible , and that is why i would like to ask you for my money back as soon as possible .
# 		love and kisses .	|	loves and kisses .
#
# Clean versions
# 		i almost agree with pat , but still what will be on the exam papers may have in serious .
# 		we 've noticed that how students are an old fashion in england .
# 		i was just looking forward to hear that i 've done something .
# 		the theatre 's thing that i could have my marks .
# 		as this i could n't take any other time to see what i am able to go .
# 		the third member of them , obviously is closed to have to ask him .
# 		3 years it could be done by the whole things and i consider of these subjects
# 		but the first problem about it , i also can ask about the facilities that danny brook did n't have on with him .
# 		from the first time i 'll give students that love , go shopping is free , but realy i hope there will be my imagination art .
# 		and the biggest show is very useful on television as people are living .
#
# Noisy versions
# 		i used to say almost everything , if it will stop with me in future times .
# 		we 've noticed that something specific wrote in our country quite young .
# 		i was just looking forward to hear that . i could n't read it .
# 		the other thing i could attend in a circle .
# 		as this i could n't get to know what i am including to go on the school .
# 		the third member that is to ask special coffee as he offered
# 		regarding the time it has been a personal things and i watched these things in spite of my life .
# 		but the first problem about i know that if there are made on the show , when you have on with someone else .
# 		from the first options to go , science museum , i think that this weekend are coming with my children are free , so i hope there will be brilliant .
# 		and the biggest show is very useful on television in a modern country 's way like medicine .
#
# Epoch   7/500 - Time  350.9, Train loss: 0.57, Val BLEU: 74.57 | 59.97 | 50.41 | 42.93
#
#
# 		 Generated 	|	 Actual
# 		then the concert started , i was called one of the staff for help , i could get into the stadium .	|	then the concert started , i was called from one of the staffs for help , finally i could get into the stadium .
# 		she can not keep secrets .	|	she is not keeping secrets .
# 		i spent some days in vienna , i had chance to help at the pearl jam where the concert had been set .	|	i spent some great days in vienna where i had the chance to help at the concert of pearl jam .
# 		it would be greatful if you would agree to change your plan .	|	it will be beutiful if you would agree to change your plan .
# 		when we arrived at the place where he said that one gold fish , started walking .	|	when we arrived at the place which it happened , one man started running away .
# 		it took us a little time to become and best friends after that we were always together .	|	it took us a few time to became best friend and after that we were always together .
# 		i still go to school and i plan go to the college next year .	|	i still go to school and i plan to go to college next year .
# 		i was very happy to receive a letter from you .	|	i was very happy to receive a letter from you .
# 		yours sincerely	|	yours sincerely
# 		at the moment of all of people can i can just arrive in the internet , i can do anything from all , so that i can buy something that i ca n't find in the shops , i can just move my computers by hand in the shop .	|	in everytime of the day i can communicate with people of all nationality of the world , i can have informations about everything , i can buy something which i ca n't find in the shops of my town , so i can do anything just clicking on the mouse
# 		it was so exciting	|	it was so exciting
# 		finally , i can say that modern technology helps people really helps their life .	|	finally , i can say that modern technology really helps people in their work .
# 		at the end , i could see that no discounts , the theatre said you was n't the perfect evening out , as it said , now i 'm a fan of this evening , because i want my money back , do n't now what the director do n't	|	at end , i could see that the advertisement said , your perfect evening out . it was n't the perfect evening . now i 'm looking for a lawyer , because i want my money back , if do n't well you know the end of this
# 		i am very glad i can choose two weeks at camp california . i am very good at basketball . i am good at this sport for my country . secondly i am good at this sport .	|	i am very glad i can chose two activities while i will at the camp . i am keen on basketball , i played in my country for 7 years . i am good diffender .
# 		unfortunately , i am very disappointed about the organisation of your company .	|	unfortunatly i am a very disappointed about organisation in your company .
# 		we 're looking forwold to your reply .	|	we 're looking forward to your reply .
# 		i helped korn at a concert they had at the auditorium .	|	i helped korn at a concert they had at the auditorium .
# 		disappointed	|	disapponted
# 		after all these reasons , my why was asking for me , and that is why i would like to ask you for my money back as soon .	|	at last , for all these reasons my evening was horrible , and that is why i would like to ask you for my money back as soon as possible .
# 		love and kisses .	|	loves and kisses .
#
# Clean versions
# 		if long time it was in living in your previous life .
# 		i went to ireland , that happened on a second subject .
# 		however , the travel is working at any time that i should take with me .
# 		then , i want to express my concern about it and helpful for over reasons .
# 		the show is so exciting when you can put a day in france and the office is totaly .
# 		because i did not have the class for about this place , but i saw your advertisement .
# 		at the moment i was having a little bit of comfort maybe i hope it was just coming back .
# 		i have expected to do the new reasons , upset when you have written about the travel .
# 		in fact we 'd like to have a pay home , at least half of car and pay back .
# 		in addition to all these plays and i have to pay for the stars just including the ticket .
#
# Noisy versions
# 		if long time it was in spain in your country ,
# 		i went to ireland , that happened on a crime .
# 		however , the work is there i moved on any distance that so i should take some weeks with me .
# 		then , i want to accept my opinions about it and helpful for over reasons .
# 		i am waiting for the idea , because you can see your theatre restaurant our children are too .
# 		because i did not complain about the entrance for this place , but i saw an advertisement .
# 		i 'm feeling hungry after the show , because she had to buy some things with her homes .
# 		i have expected to do the new things upset , when i received saturday you upset about the first time .
# 		in fact we would like to have a pay home , at least half or not for control .
# 		in addition to all these things , i have nice for the stars but with a different price .
#
# Epoch   8/500 - Time  351.0, Train loss: 0.66, Val BLEU: 74.57 | 59.96 | 50.52 | 43.1
#
#
# 		 Generated 	|	 Actual
# 		then the concert started , i was called one of the staff for help , then i could get into the stadium .	|	then the concert started , i was called from one of the staffs for help , finally i could get into the stadium .
# 		she can not keep secrets .	|	she is not keeping secrets .
# 		i spent some days before the great atmosphere in the end i had to help in the pearl where the concert began .	|	i spent some great days in vienna where i had the chance to help at the concert of pearl jam .
# 		it would be greatful if you would change to your plan .	|	it will be beutiful if you would agree to change your plan .
# 		when we arrived at the place where he said that one hour begins , walking later .	|	when we arrived at the place which it happened , one man started running away .
# 		it took us a little time to become a best friends and after we were always together .	|	it took us a few time to became best friend and after that we were always together .
# 		i still go to school and i plan go to the next year .	|	i still go to school and i plan to go to college next year .
# 		i was very happy to receive a letter from you .	|	i was very happy to receive a letter from you .
# 		yours sincerely	|	yours sincerely
# 		with the computer of the evenings , i can spend all of time in front of people , can i realize that i can get anything just on the internet , i can do anything just for the day i can store on my computers by	|	in everytime of the day i can communicate with people of all nationality of the world , i can have informations about everything , i can buy something which i ca n't find in the shops of my town , so i can do anything just clicking on the mouse
# 		it was so exciting	|	it was so exciting
# 		finally , i can say that modern technology helps people really helps their work .	|	finally , i can say that modern technology really helps people in their work .
# 		at the end , i could n't see your perfect evening , it said that the director 's holiday . i would like to start at the end of the theatre again . i do n't know why it was a very simple evening , as you want my homework	|	at end , i could see that the advertisement said , your perfect evening out . it was n't the perfect evening . now i 'm looking for a lawyer , because i want my money back , if do n't well you know the end of this
# 		i am very happy i would like to go back two weeks at the camp california . i am a good swimmer and i am quite good in this sport .	|	i am very glad i can chose two activities while i will at the camp . i am keen on basketball , i played in my country for 7 years . i am good diffender .
# 		unfortunately , i am very disappointed about the organisation of your company .	|	unfortunatly i am a very disappointed about organisation in your company .
# 		we 're looking forwold to your reply .	|	we 're looking forward to your reply .
# 		i helped korn at a concert had at the auditorium .	|	i helped korn at a concert they had at the auditorium .
# 		disappointed	|	disapponted
# 		after all these reasons , my choise was that i would like to ask you for my money back , and as soon as possible that is possible .	|	at last , for all these reasons my evening was horrible , and that is why i would like to ask you for my money back as soon as possible .
# 		love and kisses .	|	loves and kisses .
#
# Clean versions
# 		even the next years , we felt a lot of funny museum after the beach and it is also the piece of my favourite group i bought her .
# 		in the end i can do better work without any money to explain anything then i cried .
# 		every one more and the events of getting i need a much prize for such an american and further information .
# 		another problem is i was n't looking forward to the show , but it was delayed by the floor .
# 		i had rather to try from you as now i 've always wanted it because it was dangerous .
# 		there is a lot of option to be all other things .
# 		however we have to make some short shots about concerts and the concerts is difficult .
# 		please i am writing this question , and you ca n't follow your attention .
# 		i was sent to me what 's happening on the whole world but it was outside from .
# 		lastly , we were other people in the same time and i could n't bear at a particular kind of atmosphere .
#
# Noisy versions
# ...
# 		unfortunately , i am very disappointed about the organisation of your company .	|	unfortunatly i am a very disappointed about organisation in your company .
# 		we 're looking forwold to your reply .	|	we 're looking forward to your reply .
# 		i helped korn at a concert they had in the auditorium .	|	i helped korn at a concert they had at the auditorium .
# 		disappointed	|	disapponted
# 		after all these reasons , my choise was that for me , i was expecting and would ask you to return my money back as soon as possible .	|	at last , for all these reasons my evening was horrible , and that is why i would like to ask you for my money back as soon as possible .
# 		love and kisses .	|	loves and kisses .
#
# Clean versions
# 		i live in your letter and did i need to bring with me in your pocket money .
# 		we spent a lot in the way to use it and tried to the office but i 've been intrested on a plane .
# 		after all i would like to visit the train and painting .
# 		as we are all interested in accommodation and play basketball for six times , first time , there is nothing during the first time .
# 		for the show and we 're very disappointed , is closed a lot of interresting
# 		i am at the camp in california to which is i already paid .
# 		i am going to show in one of the fact that i have spent some time in the more special clothes .
# 		as for the women , i only need a camera for our being under .
# 		i would be the best experiences which had happend in the festival and i was not one of the experiences badly atmosphere .
# 		at the tv i will start to learn absolutely so playing for me .
#
# Noisy versions
# 		i live in london to your letter , and i did not need to give me in two weeks in your letter .
# 		we spent at a computer - that there and used to go to the office but on these subjects .
# 		after all , i would like to visit your theatre and painting .
# 		as we all have been interested in accommodation and playing basketball for the first time , there is nothing a 14 begins 19.30 .
# 		the discussion about we 're running , but you 're closed a lot
# 		i am at the complete of photography which is used to do on england .
# 		i am keen on to make one of the times last week in such a city , they could n't seem .
# 		as for the women , i only refused a holiday from my skin
# 		i would be the best experiences but in this festival and i had an bad way behind it 's secret .
# 		at first i will start to learn absolutely so playing for me .
#
# Epoch  73/500 - Time  351.9, Train loss: 0.59, Val BLEU: 75.33 | 61.21 | 52.03 | 44.77
#
#
# 		 Generated 	|	 Actual
# 		then , the concert started i was called one of the concert for help , i could get into the stadium .	|	then the concert started , i was called from one of the staffs for help , finally i could get into the stadium .
# 		she can not keep secrets .	|	she is not keeping secrets .
# 		i spent some days before the great way i had heard in the concert to help where you spend the time .	|	i spent some great days in vienna where i had the chance to help at the concert of pearl jam .
# 		it would be greatful if you would agree to change your plan .	|	it will be beutiful if you would agree to change your plan .
# 		when we arrived at the place where it happened , one man started running five minutes .	|	when we arrived at the place which it happened , one man started running away .
# 		it took us a little time to become more and best friends after that we are always together .	|	it took us a few time to became best friend and after that we were always together .
# 		i still go to school and i have to go to college next year .	|	i still go to school and i plan to go to college next year .
# 		i was very happy to receive a letter from you .	|	i was very happy to receive a letter from you .
# 		yours sincerely	|	yours sincerely
# 		at the end of the day i can communicate with people of every day , even if i can buy everything i can shop from information , instead of everything . i want to buy something that i ca n't imagine in the other store in the world , when	|	in everytime of the day i can communicate with people of all nationality of the world , i can have informations about everything , i can buy something which i ca n't find in the shops of my town , so i can do anything just clicking on the mouse
# 		it was so exciting	|	it was so exciting
# 		finally , i can say that modern technologies people really work in their house .	|	finally , i can say that modern technology really helps people in their work .
# 		at the end , i could n't see your perfect restaurant , it was the only thing that i want to say it , a actually , the end of june . i did n't understand the end of this month , as you want to know about my money	|	at end , i could see that the advertisement said , your perfect evening out . it was n't the perfect evening . now i 'm looking for a lawyer , because i want my money back , if do n't well you know the end of this
# 		i am very happy i would prefer to go two weeks at the camp california . i am a good swimmer and i am quite good in this sport . secondly for my country .	|	i am very glad i can chose two activities while i will at the camp . i am keen on basketball , i played in my country for 7 years . i am good diffender .
# 		unfortunately , i am very disappointed about the treatment of your company .	|	unfortunatly i am a very disappointed about organisation in your company .
# 		we 're looking forwold to your reply .	|	we 're looking forward to your reply .
# 		i helped korn at a concert they had at the auditorium .	|	i helped korn at a concert they had at the auditorium .
# 		disappointed	|	disapponted
# 		after all these reasons , my choise was that for me , i was expecting and disappointed that if you would ask me my money back as soon as possible .	|	at last , for all these reasons my evening was horrible , and that is why i would like to ask you for my money back as soon as possible .
# 		love and kisses .	|	loves and kisses .
#
# Clean versions
# 		we can choose another person to do this problem with the health at that time .
# 		i am so looking to get into modern technology .
# 		write me a wide style of yourself i need to stay in contact others .
# 		i had a chance to take part in your programme ,
# 		your job is only in a way of my job however i went back at least an hour late .
# 		i find a lot of information , to say that it was too late .
# 		i like to study my old so in the middle you can try many problems .
# 		first of really , i have won it for twelve years and eating under the circle theatre which is situated close and strange things ?
# 		besides to my home of photos , i am quite comfortable and comfortable .
# 		i 'm keen on part of the evening i had expected only because i arrive late of the other restaurant if its state 's local school .
#
# Noisy versions
# 		we can choose another person to do this problem with the health at that time .
# 		i am looking forward to get a lot of money .
# 		please phone me and i 'm going to spend most in a real world
# 		i had a chance to take part , like the colour yours happen .
# 		your job is only a thing of my grandparents for the worst evening i am at christmas .
# 		i find a lot of information , to say that it was too late .
# 		i am very busy with my shopping to do the travel to the country .
# 		first of really , i have won it for eating a little survey and which is the dream quickly and strange points ?
# 		besides , i want my knowledge of photos and comfortable flats .
# 		i 'm keen on part of the theatre i could stand when i watch television 's local restaurant but unfortunately , i would arrive late .
#
# Epoch  74/500 - Time  351.6, Train loss: 0.56, Val BLEU: 75.67 | 61.55 | 52.41 | 45.22
#
#
# 		 Generated 	|	 Actual
# 		then the concert started , i was called one of the concert for help , i could get into the stadium .	|	then the concert started , i was called from one of the staffs for help , finally i could get into the stadium .
# 		she can not keep secrets .	|	she is not keeping secrets .
# 		i spent some days in vienna where i had the chance to help at the pearl jam where the concert had been of coming .	|	i spent some great days in vienna where i had the chance to help at the concert of pearl jam .
# 		it would be greatful if you would change to our mind .	|	it will be beutiful if you would agree to change your plan .
# 		when we arrived at the place where it happened , one hour 15 minutes later .	|	when we arrived at the place which it happened , one man started running away .
# 		it took us a little bit to spend together and after that it was most good friends .	|	it took us a few time to became best friend and after that we were always together .
# 		i still go to school and i have to go to college next year .	|	i still go to school and i plan to go to college next year .
# 		i was very happy to receive a letter from you .	|	i was very happy to receive a letter from you .
# 		yours sincerely	|	yours sincerely
# 		at the moment of all people can from my computer , i can just use all of the computer , everything else , can i get up in the shops which i can just ever , i can do anything in my newspaper when i want to shop by clicking	|	in everytime of the day i can communicate with people of all nationality of the world , i can have informations about everything , i can buy something which i ca n't find in the shops of my town , so i can do anything just clicking on the mouse
# 		it was so exciting	|	it was so exciting
# 		finally , i can say that modern technology helps people really helps their work .	|	finally , i can say that modern technology really helps people in their work .
# 		at the end , i could see that no discounts , the theatre restaurant was really busy . it said the busy sould . i would like to start my money back because of this work , do n't now i 'm a full refund of this	|	at end , i could see that the advertisement said , your perfect evening out . it was n't the perfect evening . now i 'm looking for a lawyer , because i want my money back , if do n't well you know the end of this
# 		i am very happy i would like to go two weeks at the camp - although i am a full-time student . i am good at this sport with old team . secondly .	|	i am very glad i can chose two activities while i will at the camp . i am keen on basketball , i played in my country for 7 years . i am good diffender .
# 		unfortunately , i am very disappointed about the organisation of your company .	|	unfortunatly i am a very disappointed about organisation in your company .
# 		we 're looking forwold to your reply .	|	we 're looking forward to your reply .
# 		i helped korn at a concert they had in the auditorium .	|	i helped korn at a concert they had at the auditorium .
# 		disappointed	|	disapponted
# 		after all these reasons , my choise was that , why i was expecting and ask you to refund me , as soon as possible .	|	at last , for all these reasons my evening was horrible , and that is why i would like to ask you for my money back as soon as possible .
# 		love and kisses .	|	loves and kisses .
#
# Clean versions
# 		i 've just to disappoint the poor thing , i can bring my camera is in the camp , but also the things there are my offered work for the concert .
# 		to conclude i would like to have another free time , there heard my teachers very well .
# 		i have to make a successful more attractive .
# 		here ,
# 		i do n't like the water from august , just i am pleasant to go into my joy .
# 		the audience is just one and enjoyable spending money raspsquo .
# 		to produce a present for you , it 's unbelievable for doing that we have a little and the plan finished .
# 		it was very special because she 'd like to talk a couple of coming article stories again and the heart .
# 		you 've been very happy to show , because in his brothers , and a night of mine sister .
# 		i have to look for another person which is very disappointing if i know the new school , i will start fine .
#
# Noisy versions
# 		i 'm a great boy who talked to the things that my favourite actor , and the light is in my work at the concert .
# 		to conclude i would like to have another free time , there , my teachers very well .
# 		i have to make an international more courses .
# 		here ,
# 		i do n't like to participate from the sun , just because i want to go back by myself .
# 		the audience is going to spend more and spending one of her new imagination ?
# 		to produce a present for you , it 's unbelievable for doing that we have a little dress , we stopped at the time .
# 		it was very special because she 'd like to talk a couple of coming stories again seeing the stories .
# 		you 've been very happy to show , because in our college and he told me a huge .
# 		i have to search him for this book which is known i can see how busy during the stay .
#
# Epoch  75/500 - Time  351.5, Train loss: 0.55, Val BLEU: 75.75 | 61.6 | 52.42 | 45.14
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-1e32123e99b9> in <module>()
#      66
#      67
# ---> 68 model.train(input_train, input_val, output_train, output_val, label_train, label_val, checkpoint = checkpoint)
#      69 log_writer.close()
#      70
#
# <ipython-input-6-5f8b8c41feff> in train(self, input_train, input_val, output_train, output_val, label_train, label_val, checkpoint_return, checkpoint)
#     380                                        self.target_sentence_length: output_sent_lengths,
#     381                                        self.keep_prob: self.dropout_keep_prob,
# --> 382                                        self.lambda_coeff: self.lambda_val,
#     383                                        })
#     384
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     948     try:
#     949       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 950                          run_metadata_ptr)
#     951       if run_metadata:
#     952         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1171     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1172       results = self._do_run(handle, final_targets, final_fetches,
# -> 1173                              feed_dict_tensor, options, run_metadata)
#    1174     else:
#    1175       results = []
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1348     if handle is None:
#    1349       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1350                            run_metadata)
#    1351     else:
#    1352       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1354   def _do_call(self, fn, *args):
#    1355     try:
# -> 1356       return fn(*args)
#    1357     except errors.OpError as e:
#    1358       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1339       self._extend_graph()
#    1340       return self._call_tf_sessionrun(
# -> 1341           options, feed_dict, fetch_list, target_list, run_metadata)
#    1342
#    1343     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1427     return tf_session.TF_SessionRun_wrapper(
#    1428         self._session, options, feed_dict, fetch_list, target_list,
# -> 1429         run_metadata)
#    1430
#    1431   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
model = DetWAEModel(config,
                    embeddings_matrix,
                    word_index)

checkpoint = '/content/drive/My Drive/models/full_snli_lambdaWAE3.0_batch64_kernel_IMQ_num_tokens_50/75.ckpt'
    
model.random_sample_save(checkpoint = checkpoint)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0820 08:22:56.853343 139793741301632 deprecation.py:323] From <ipython-input-6-5198b184d624>:113: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# W0820 08:22:56.855214 139793741301632 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/rnn.py:464: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# [INFO] Building Model ...
# W0820 08:22:57.517915 139793741301632 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0820 08:22:57.668668 139793741301632 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/rnn.py:244: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0820 08:22:59.384200 139793741301632 deprecation.py:506] From <ipython-input-6-5198b184d624>:216: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# W0820 08:23:06.563290 139793741301632 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# [INFO]: CHECKPOINT RESTORED
# NUMBER OF SAMPLES:  600000
